# %%
from __future__ import print_function
from __future__ import division

import matplotlib.pyplot as plt
import numpy as np
from numpy.linalg import norm
from math import sqrt
import sklearn
from sklearn.linear_model import LogisticRegression
import pickle
import time
import torch

from utils import test_accuracy, projection, veccos, binary_search_cx, \
                  find_exp_score, find_slab_score, project_l2_centroid, \
                  project_l2_centroid_straight, project_slab, project_slab_straight,\
                  contaminate_dataset

from attackers import StraightAttack, SemiOnlineAttack, ConcentratedAttack, GreedyAttack
# Out:
# /home/yizhenwang/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/yizhenwang/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/yizhenwang/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/yizhenwang/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/yizhenwang/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/yizhenwang/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
## fully online experiment

def experiment(dataset, taus=None):
    
    filepath = "./data/"+dataset+"/"
    clf = LogisticRegression(fit_intercept=False, solver='liblinear')
    if (taus==None):
        n_taus = 5
    else:
        n_taus = len(taus)
    res = [0 for a in range(n_taus)]
    
    for i in range(n_exp):    
        print ("Running the {}-th experiment".format(i))
        start_time = time.time()
        filename = filepath+str(i)
        with open(filename,"rb") as f:
            datasets = pickle.load(f)

        X_init, Y_init = datasets[0] # generate defense constraints and init w if necessary.
        X_clean, Y_clean = datasets[1] # the clean data stream
        X_valid, Y_valid = datasets[2] # validation set
        X_test, Y_test = datasets[3]   # the actual test set

        clf.fit(X_init, Y_init)
        w_0 = np.zeros((1,d))
        print ("Initial accuracy is {}".format(test_accuracy(X_test, Y_test, w_0)))
        w_t = -clf.coef_
        w_t /= norm(w_t)
        print ("Target accuracy is {}".format(test_accuracy(X_test, Y_test, w_t)))

        if attack_method == "simplistic":
            attacker = StraightAttack()
            attacker.set_param(datasets, w_0, w_t, R, eta, 
                                        defense, n_iter_warmup, n_attack) 
        elif attack_method == "greedy":
            attacker = GreedyAttack()
            attacker.set_param(datasets, w_0, w_t, R, eta, 
                                        defense, n_iter_warmup, n_attack) 
        elif attack_method == "concentrated":
            attacker = ConcentratedAttack()
            attacker.set_param(datasets, w_0, w_t, R, eta, 
                                        defense, n_iter_warmup, n_attack) 
        elif attack_method == "semi-online":
            attacker = SemiOnlineAttack()
            X_adv, Y_adv = X_clean[:n_attack, :], Y_clean[:n_attack]
            attacker.set_param(datasets, w_0, w_t, R, eta, 
                                        defense, n_iter_warmup, n_attack, (-X_adv, Y_adv))

        global loc
        
        attacker.set_init_set(X_init, Y_init)
        if defense_method == "slab":
            scores = attacker.slab_scores()[-1]
        elif defense_method == "norm":
            scores = attacker.l2_norms()[-1]
        elif defense_method == "L2":
            scores = attacker.l2_distances_to_centroid()[-1]
        
        tau_levels = [0.3, 0.5, 0.7, 0.9, 1]
        taus = [scores[int(tau_level*len(scores))-1] for tau_level in tau_levels]
        print (taus)
        w_list = [[] for tau in taus]
        res = [[] for tau in taus]
        accs = [[] for tau in taus]
        online_res = [[] for tau in taus]
        for j,tau in enumerate(taus):

            attacker.set_defense_threshold(defense_method, tau)
            attacker.set_defense_range(defense_range)
            attacker.set_init_set(X_init, Y_init)

            i_clean = 0
            
            for k in range(n_horizon):
                if loc[k]: #attack
                    if attack_method == "semi-online":
                        attacker.set_param_lite(attacker.w_curr, w_t, 0, 1, 
                                           (-X_clean[k].reshape(1,-1), Y_clean[k].reshape(1)))

                    pt = attacker.find_best_poisoning_points()
                    attacker.update_w(pt)
                    online_res[j].append(0)
                else:      #update on clean point
                    pt = (attacker.X_clean[k,:], attacker.Y_clean[k])
                    online_res[j].append(round(test_accuracy(X_clean[k].reshape(1,-1), 
                                                             Y_clean[k].reshape(1),
                                                             attacker.w_curr)))
                    if attacker.meet_constraints(pt):
                        attacker.update_w(pt)
                    i_clean += 1
                acc = test_accuracy(X_test, Y_test, attacker.w_curr)
                w_list[j].append(attacker.w_curr)
                accs[j].append(acc)
                if k%50==0:
                    print ("Accuracy at time {} is {}".format(k, acc))
                
            print ("acc on clean stream is", sum(online_res[j])/i_clean)
                    
            print (tau, sum(accs[j])/n_horizon)
            res[j] = (sum(accs[j])/n_horizon)
            attacker.reset()
            print (res)
            print("--- %s seconds ---" % (time.time() - start_time))
            
        results = [res, online_res, accs, w_list, taus, loc]
        filepath = "_".join(["./results/fully", dataset, attack_method, defense_method, defense_range, str(i)])
        print (filepath)
        with open(filepath, "wb") as f:
            pickle.dump(results, f)
        filepath = "_".join(["./results/fully", dataset, attack_method, defense_method, defense_range, str(i)])
        print (filepath)    
        with open(filepath, "rb") as f:
            results = pickle.load(f)
        res, online_res, accs, w_list, taus, loc = results    
    return w_list, (X_test, Y_test)

# %%
n_exp = 1
d, eta = 784, 0.01
n_attack, n_clean, n_init, n_test, n_valid = 100, 8000, 1000, 1000, 500
n_iter_warmup = n_clean
n_horizon = 1000
attack_chance = 0.1
dataset = "fashionMNIST"
loc = (np.random.permutation(n_horizon) < n_horizon*attack_chance)

R = 12

# %%
defense_method = "norm"
defense = {defense_method:0}
attack_methods = ["simplistic", "greedy", "semi-online"]
for attack_method in attack_methods:
    defense_range = "all-pts"
    w_list1, (X_test, Y_test) = experiment(dataset)
    res1 = [test_accuracy(X_test, Y_test, w) for w in w_list1[-1]]
# Out:
# Running the 0-th experiment
# Initial accuracy is 0.499
# Target accuracy is 0.01
# [6.966801607380625, 7.542731555316739, 8.550132474332946, 10.200196326442075, 15.78008818241856]
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.796
# Accuracy at time 100 is 0.762
# Accuracy at time 150 is 0.794
# Accuracy at time 200 is 0.796
# Accuracy at time 250 is 0.806
# Accuracy at time 300 is 0.776
# Accuracy at time 350 is 0.74
# Accuracy at time 400 is 0.81
# Accuracy at time 450 is 0.807
# Accuracy at time 500 is 0.806
# Accuracy at time 550 is 0.768
# Accuracy at time 600 is 0.765
# Accuracy at time 650 is 0.755
# Accuracy at time 700 is 0.677
# Accuracy at time 750 is 0.74
# Accuracy at time 800 is 0.719
# Accuracy at time 850 is 0.711
# Accuracy at time 900 is 0.659
# Accuracy at time 950 is 0.636
# acc on clean stream is 0.7422222222222222
# 6.966801607380625 0.7473879999999986
# [0.7473879999999986, [], [], [], []]
# --- 4.467849254608154 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.835
# Accuracy at time 100 is 0.83
# Accuracy at time 150 is 0.849
# Accuracy at time 200 is 0.848
# Accuracy at time 250 is 0.844
# Accuracy at time 300 is 0.808
# Accuracy at time 350 is 0.754
# Accuracy at time 400 is 0.828
# Accuracy at time 450 is 0.811
# Accuracy at time 500 is 0.805
# Accuracy at time 550 is 0.776
# Accuracy at time 600 is 0.774
# Accuracy at time 650 is 0.754
# Accuracy at time 700 is 0.657
# Accuracy at time 750 is 0.73
# Accuracy at time 800 is 0.74
# Accuracy at time 850 is 0.748
# Accuracy at time 900 is 0.705
# Accuracy at time 950 is 0.733
# acc on clean stream is 0.7855555555555556
# 7.542731555316739 0.7746149999999993
# [0.7473879999999986, 0.7746149999999993, [], [], []]
# --- 8.068647146224976 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.852
# Accuracy at time 100 is 0.873
# Accuracy at time 150 is 0.879
# Accuracy at time 200 is 0.869
# Accuracy at time 250 is 0.859
# Accuracy at time 300 is 0.814
# Accuracy at time 350 is 0.76
# Accuracy at time 400 is 0.823
# Accuracy at time 450 is 0.817
# Accuracy at time 500 is 0.832
# Accuracy at time 550 is 0.786
# Accuracy at time 600 is 0.793
# Accuracy at time 650 is 0.758
# Accuracy at time 700 is 0.673
# Accuracy at time 750 is 0.745
# Accuracy at time 800 is 0.756
# Accuracy at time 850 is 0.811
# Accuracy at time 900 is 0.757
# Accuracy at time 950 is 0.754
# acc on clean stream is 0.8066666666666666
# 8.550132474332946 0.7974260000000003
# [0.7473879999999986, 0.7746149999999993, 0.7974260000000003, [], []]
# --- 11.53917145729065 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.868
# Accuracy at time 100 is 0.89
# Accuracy at time 150 is 0.887
# Accuracy at time 200 is 0.887
# Accuracy at time 250 is 0.863
# Accuracy at time 300 is 0.801
# Accuracy at time 350 is 0.724
# Accuracy at time 400 is 0.815
# Accuracy at time 450 is 0.819
# Accuracy at time 500 is 0.849
# Accuracy at time 550 is 0.8
# Accuracy at time 600 is 0.79
# Accuracy at time 650 is 0.751
# Accuracy at time 700 is 0.694
# Accuracy at time 750 is 0.785
# Accuracy at time 800 is 0.783
# Accuracy at time 850 is 0.829
# Accuracy at time 900 is 0.768
# Accuracy at time 950 is 0.756
# acc on clean stream is 0.8088888888888889
# 10.200196326442075 0.806305999999999
# [0.7473879999999986, 0.7746149999999993, 0.7974260000000003, 0.806305999999999, []]
# --- 15.316282510757446 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.882
# Accuracy at time 100 is 0.886
# Accuracy at time 150 is 0.882
# Accuracy at time 200 is 0.883
# Accuracy at time 250 is 0.867
# Accuracy at time 300 is 0.798
# Accuracy at time 350 is 0.722
# Accuracy at time 400 is 0.818
# Accuracy at time 450 is 0.819
# Accuracy at time 500 is 0.849
# Accuracy at time 550 is 0.801
# Accuracy at time 600 is 0.79
# Accuracy at time 650 is 0.748
# Accuracy at time 700 is 0.724
# Accuracy at time 750 is 0.799
# Accuracy at time 800 is 0.796
# Accuracy at time 850 is 0.843
# Accuracy at time 900 is 0.773
# Accuracy at time 950 is 0.761
# acc on clean stream is 0.8111111111111111
# 15.78008818241856 0.8107259999999998
# [0.7473879999999986, 0.7746149999999993, 0.7974260000000003, 0.806305999999999, 0.8107259999999998]
# --- 19.41523766517639 seconds ---
# ./results/fully_fashionMNIST_simplistic_norm_all-pts_0
# ./results/fully_fashionMNIST_simplistic_norm_all-pts_0
# Running the 0-th experiment
# Initial accuracy is 0.499
# Target accuracy is 0.01
# [6.966801607380625, 7.542731555316739, 8.550132474332946, 10.200196326442075, 15.78008818241856]
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.689
# Accuracy at time 100 is 0.361
# Accuracy at time 150 is 0.701
# Accuracy at time 200 is 0.675
# Accuracy at time 250 is 0.7
# Accuracy at time 300 is 0.457
# Accuracy at time 350 is 0.15
# Accuracy at time 400 is 0.751
# Accuracy at time 450 is 0.775
# Accuracy at time 500 is 0.792
# Accuracy at time 550 is 0.683
# Accuracy at time 600 is 0.579
# Accuracy at time 650 is 0.597
# Accuracy at time 700 is 0.103
# Accuracy at time 750 is 0.642
# Accuracy at time 800 is 0.651
# Accuracy at time 850 is 0.699
# Accuracy at time 900 is 0.458
# Accuracy at time 950 is 0.506
# acc on clean stream is 0.5188888888888888
# 6.966801607380625 0.5510519999999984
# [0.5510519999999984, [], [], [], []]
# --- 74.12286400794983 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.794
# Accuracy at time 100 is 0.776
# Accuracy at time 150 is 0.824
# Accuracy at time 200 is 0.807
# Accuracy at time 250 is 0.826
# Accuracy at time 300 is 0.679
# Accuracy at time 350 is 0.351
# Accuracy at time 400 is 0.823
# Accuracy at time 450 is 0.816
# Accuracy at time 500 is 0.829
# Accuracy at time 550 is 0.768
# Accuracy at time 600 is 0.773
# Accuracy at time 650 is 0.745
# Accuracy at time 700 is 0.409
# Accuracy at time 750 is 0.73
# Accuracy at time 800 is 0.774
# Accuracy at time 850 is 0.784
# Accuracy at time 900 is 0.727
# Accuracy at time 950 is 0.764
# acc on clean stream is 0.7266666666666667
# 7.542731555316739 0.7349570000000005
# [0.5510519999999984, 0.7349570000000005, [], [], []]
# --- 183.8909158706665 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.793
# Accuracy at time 100 is 0.831
# Accuracy at time 150 is 0.862
# Accuracy at time 200 is 0.855
# Accuracy at time 250 is 0.849
# Accuracy at time 300 is 0.755
# Accuracy at time 350 is 0.721
# Accuracy at time 400 is 0.839
# Accuracy at time 450 is 0.851
# Accuracy at time 500 is 0.862
# Accuracy at time 550 is 0.827
# Accuracy at time 600 is 0.805
# Accuracy at time 650 is 0.772
# Accuracy at time 700 is 0.585
# Accuracy at time 750 is 0.778
# Accuracy at time 800 is 0.801
# Accuracy at time 850 is 0.847
# Accuracy at time 900 is 0.792
# Accuracy at time 950 is 0.787
# acc on clean stream is 0.7844444444444445
# 8.550132474332946 0.7902010000000027
# [0.5510519999999984, 0.7349570000000005, 0.7902010000000027, [], []]
# --- 294.9099750518799 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.809
# Accuracy at time 100 is 0.843
# Accuracy at time 150 is 0.867
# Accuracy at time 200 is 0.879
# Accuracy at time 250 is 0.849
# Accuracy at time 300 is 0.703
# Accuracy at time 350 is 0.692
# Accuracy at time 400 is 0.848
# Accuracy at time 450 is 0.856
# Accuracy at time 500 is 0.883
# Accuracy at time 550 is 0.818
# Accuracy at time 600 is 0.796
# Accuracy at time 650 is 0.762
# Accuracy at time 700 is 0.664
# Accuracy at time 750 is 0.829
# Accuracy at time 800 is 0.821
# Accuracy at time 850 is 0.853
# Accuracy at time 900 is 0.78
# Accuracy at time 950 is 0.789
# acc on clean stream is 0.7966666666666666
# 10.200196326442075 0.7966660000000001
# [0.5510519999999984, 0.7349570000000005, 0.7902010000000027, 0.7966660000000001, []]
# --- 393.5705666542053 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.735
# Accuracy at time 100 is 0.733
# Accuracy at time 150 is 0.827
# Accuracy at time 200 is 0.864
# Accuracy at time 250 is 0.817
# Accuracy at time 300 is 0.544
# Accuracy at time 350 is 0.541
# Accuracy at time 400 is 0.823
# Accuracy at time 450 is 0.819
# Accuracy at time 500 is 0.855
# Accuracy at time 550 is 0.635
# Accuracy at time 600 is 0.716
# Accuracy at time 650 is 0.704
# Accuracy at time 700 is 0.558
# Accuracy at time 750 is 0.818
# Accuracy at time 800 is 0.79
# Accuracy at time 850 is 0.86
# Accuracy at time 900 is 0.618
# Accuracy at time 950 is 0.76
# acc on clean stream is 0.6866666666666666
# 15.78008818241856 0.6919740000000008
# [0.5510519999999984, 0.7349570000000005, 0.7902010000000027, 0.7966660000000001, 0.6919740000000008]
# --- 492.52286291122437 seconds ---
# ./results/fully_fashionMNIST_greedy_norm_all-pts_0
# ./results/fully_fashionMNIST_greedy_norm_all-pts_0
# Running the 0-th experiment
# Initial accuracy is 0.499
# Target accuracy is 0.01
# [6.966801607380625, 7.542731555316739, 8.550132474332946, 10.200196326442075, 15.78008818241856]
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.683
# Accuracy at time 100 is 0.012
# Accuracy at time 150 is 0.821
# Accuracy at time 200 is 0.818
# Accuracy at time 250 is 0.86
# Accuracy at time 300 is 0.752
# Accuracy at time 350 is 0.239
# Accuracy at time 400 is 0.886
# Accuracy at time 450 is 0.877
# Accuracy at time 500 is 0.868
# Accuracy at time 550 is 0.757
# Accuracy at time 600 is 0.567
# Accuracy at time 650 is 0.662
# Accuracy at time 700 is 0.012
# Accuracy at time 750 is 0.885
# Accuracy at time 800 is 0.811
# Accuracy at time 850 is 0.834
# Accuracy at time 900 is 0.521
# Accuracy at time 950 is 0.671
# acc on clean stream is 0.58
# 6.966801607380625 0.6092459999999981
# [0.6092459999999981, [], [], [], []]
# --- 198.80798864364624 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.839
# Accuracy at time 100 is 0.808
# Accuracy at time 150 is 0.852
# Accuracy at time 200 is 0.853
# Accuracy at time 250 is 0.862
# Accuracy at time 300 is 0.765
# Accuracy at time 350 is 0.463
# Accuracy at time 400 is 0.892
# Accuracy at time 450 is 0.877
# Accuracy at time 500 is 0.872
# Accuracy at time 550 is 0.819
# Accuracy at time 600 is 0.811
# Accuracy at time 650 is 0.779
# Accuracy at time 700 is 0.131
# Accuracy at time 750 is 0.885
# Accuracy at time 800 is 0.856
# Accuracy at time 850 is 0.865
# Accuracy at time 900 is 0.795
# Accuracy at time 950 is 0.817
# acc on clean stream is 0.7544444444444445
# 7.542731555316739 0.7761700000000022
# [0.6092459999999981, 0.7761700000000022, [], [], []]
# --- 419.559885263443 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.841
# Accuracy at time 100 is 0.862
# Accuracy at time 150 is 0.877
# Accuracy at time 200 is 0.873
# Accuracy at time 250 is 0.872
# Accuracy at time 300 is 0.818
# Accuracy at time 350 is 0.812
# Accuracy at time 400 is 0.88
# Accuracy at time 450 is 0.883
# Accuracy at time 500 is 0.886
# Accuracy at time 550 is 0.847
# Accuracy at time 600 is 0.826
# Accuracy at time 650 is 0.798
# Accuracy at time 700 is 0.593
# Accuracy at time 750 is 0.887
# Accuracy at time 800 is 0.863
# Accuracy at time 850 is 0.883
# Accuracy at time 900 is 0.828
# Accuracy at time 950 is 0.82
# acc on clean stream is 0.8122222222222222
# 8.550132474332946 0.8188529999999987
# [0.6092459999999981, 0.7761700000000022, 0.8188529999999987, [], []]
# --- 638.7885737419128 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.862
# Accuracy at time 100 is 0.87
# Accuracy at time 150 is 0.876
# Accuracy at time 200 is 0.887
# Accuracy at time 250 is 0.874
# Accuracy at time 300 is 0.758
# Accuracy at time 350 is 0.839
# Accuracy at time 400 is 0.888
# Accuracy at time 450 is 0.887
# Accuracy at time 500 is 0.895
# Accuracy at time 550 is 0.854
# Accuracy at time 600 is 0.807
# Accuracy at time 650 is 0.79
# Accuracy at time 700 is 0.748
# Accuracy at time 750 is 0.894
# Accuracy at time 800 is 0.867
# Accuracy at time 850 is 0.879
# Accuracy at time 900 is 0.805
# Accuracy at time 950 is 0.826
# acc on clean stream is 0.8177777777777778
# 10.200196326442075 0.8259450000000008
# [0.6092459999999981, 0.7761700000000022, 0.8188529999999987, 0.8259450000000008, []]
# --- 791.3956475257874 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.841
# Accuracy at time 100 is 0.805
# Accuracy at time 150 is 0.848
# Accuracy at time 200 is 0.9
# Accuracy at time 250 is 0.875
# Accuracy at time 300 is 0.751
# Accuracy at time 350 is 0.734
# Accuracy at time 400 is 0.865
# Accuracy at time 450 is 0.85
# Accuracy at time 500 is 0.87
# Accuracy at time 550 is 0.676
# Accuracy at time 600 is 0.763
# Accuracy at time 650 is 0.78
# Accuracy at time 700 is 0.631
# Accuracy at time 750 is 0.888
# Accuracy at time 800 is 0.843
# Accuracy at time 850 is 0.878
# Accuracy at time 900 is 0.639
# Accuracy at time 950 is 0.811
# acc on clean stream is 0.7322222222222222
# 15.78008818241856 0.7380580000000001
# [0.6092459999999981, 0.7761700000000022, 0.8188529999999987, 0.8259450000000008, 0.7380580000000001]
# --- 925.9846069812775 seconds ---
# ./results/fully_fashionMNIST_semi-online_norm_all-pts_0
# ./results/fully_fashionMNIST_semi-online_norm_all-pts_0

# %%
defense_method = "L2"
defense = {defense_method:0}

for attack_method in attack_methods:
    defense_range = "all-pts"
    w_list2, (X_test, Y_test) = experiment(dataset)
    res2 = [test_accuracy(X_test, Y_test, w) for w in w_list2[-1]]
# Out:
# Running the 0-th experiment
# Initial accuracy is 0.499
# Target accuracy is 0.01
# [5.873603364436745, 6.905138157495109, 7.852809741062167, 9.04583067227028, 14.03859315480033]
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.84
# Accuracy at time 100 is 0.849
# Accuracy at time 150 is 0.853
# Accuracy at time 200 is 0.846
# Accuracy at time 250 is 0.847
# Accuracy at time 300 is 0.835
# Accuracy at time 350 is 0.82
# Accuracy at time 400 is 0.833
# Accuracy at time 450 is 0.835
# Accuracy at time 500 is 0.836
# Accuracy at time 550 is 0.829
# Accuracy at time 600 is 0.826
# Accuracy at time 650 is 0.825
# Accuracy at time 700 is 0.808
# Accuracy at time 750 is 0.812
# Accuracy at time 800 is 0.809
# Accuracy at time 850 is 0.81
# Accuracy at time 900 is 0.802
# Accuracy at time 950 is 0.801
# acc on clean stream is 0.8255555555555556
# 5.873603364436745 0.8221759999999976
# [0.8221759999999976, [], [], [], []]
# --- 3.6038308143615723 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.856
# Accuracy at time 100 is 0.863
# Accuracy at time 150 is 0.87
# Accuracy at time 200 is 0.86
# Accuracy at time 250 is 0.86
# Accuracy at time 300 is 0.845
# Accuracy at time 350 is 0.831
# Accuracy at time 400 is 0.841
# Accuracy at time 450 is 0.844
# Accuracy at time 500 is 0.847
# Accuracy at time 550 is 0.841
# Accuracy at time 600 is 0.84
# Accuracy at time 650 is 0.829
# Accuracy at time 700 is 0.812
# Accuracy at time 750 is 0.82
# Accuracy at time 800 is 0.812
# Accuracy at time 850 is 0.822
# Accuracy at time 900 is 0.821
# Accuracy at time 950 is 0.82
# acc on clean stream is 0.8311111111111111
# 6.905138157495109 0.8358400000000019
# [0.8221759999999976, 0.8358400000000019, [], [], []]
# --- 6.445448875427246 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.864
# Accuracy at time 100 is 0.879
# Accuracy at time 150 is 0.879
# Accuracy at time 200 is 0.885
# Accuracy at time 250 is 0.876
# Accuracy at time 300 is 0.857
# Accuracy at time 350 is 0.835
# Accuracy at time 400 is 0.861
# Accuracy at time 450 is 0.866
# Accuracy at time 500 is 0.866
# Accuracy at time 550 is 0.855
# Accuracy at time 600 is 0.852
# Accuracy at time 650 is 0.844
# Accuracy at time 700 is 0.827
# Accuracy at time 750 is 0.836
# Accuracy at time 800 is 0.837
# Accuracy at time 850 is 0.847
# Accuracy at time 900 is 0.833
# Accuracy at time 950 is 0.834
# acc on clean stream is 0.8533333333333334
# 7.852809741062167 0.8524789999999994
# [0.8221759999999976, 0.8358400000000019, 0.8524789999999994, [], []]
# --- 9.27046799659729 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.875
# Accuracy at time 100 is 0.88
# Accuracy at time 150 is 0.885
# Accuracy at time 200 is 0.885
# Accuracy at time 250 is 0.883
# Accuracy at time 300 is 0.857
# Accuracy at time 350 is 0.824
# Accuracy at time 400 is 0.858
# Accuracy at time 450 is 0.864
# Accuracy at time 500 is 0.871
# Accuracy at time 550 is 0.868
# Accuracy at time 600 is 0.855
# Accuracy at time 650 is 0.841
# Accuracy at time 700 is 0.82
# Accuracy at time 750 is 0.845
# Accuracy at time 800 is 0.836
# Accuracy at time 850 is 0.855
# Accuracy at time 900 is 0.835
# Accuracy at time 950 is 0.83
# acc on clean stream is 0.8588888888888889
# 9.04583067227028 0.8549330000000002
# [0.8221759999999976, 0.8358400000000019, 0.8524789999999994, 0.8549330000000002, []]
# --- 12.160061597824097 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.894
# Accuracy at time 100 is 0.889
# Accuracy at time 150 is 0.885
# Accuracy at time 200 is 0.885
# Accuracy at time 250 is 0.869
# Accuracy at time 300 is 0.805
# Accuracy at time 350 is 0.731
# Accuracy at time 400 is 0.818
# Accuracy at time 450 is 0.826
# Accuracy at time 500 is 0.849
# Accuracy at time 550 is 0.802
# Accuracy at time 600 is 0.789
# Accuracy at time 650 is 0.753
# Accuracy at time 700 is 0.729
# Accuracy at time 750 is 0.803
# Accuracy at time 800 is 0.797
# Accuracy at time 850 is 0.845
# Accuracy at time 900 is 0.773
# Accuracy at time 950 is 0.761
# acc on clean stream is 0.8155555555555556
# 14.03859315480033 0.8134550000000006
# [0.8221759999999976, 0.8358400000000019, 0.8524789999999994, 0.8549330000000002, 0.8134550000000006]
# --- 14.96425986289978 seconds ---
# ./results/fully_fashionMNIST_simplistic_L2_all-pts_0
# ./results/fully_fashionMNIST_simplistic_L2_all-pts_0
# Running the 0-th experiment
# Initial accuracy is 0.499
# Target accuracy is 0.01
# [5.873603364436745, 6.905138157495109, 7.852809741062167, 9.04583067227028, 14.03859315480033]
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.849
# Accuracy at time 100 is 0.85
# Accuracy at time 150 is 0.853
# Accuracy at time 200 is 0.847
# Accuracy at time 250 is 0.849
# Accuracy at time 300 is 0.844
# Accuracy at time 350 is 0.832
# Accuracy at time 400 is 0.846
# Accuracy at time 450 is 0.846
# Accuracy at time 500 is 0.845
# Accuracy at time 550 is 0.841
# Accuracy at time 600 is 0.842
# Accuracy at time 650 is 0.843
# Accuracy at time 700 is 0.829
# Accuracy at time 750 is 0.83
# Accuracy at time 800 is 0.829
# Accuracy at time 850 is 0.834
# Accuracy at time 900 is 0.829
# Accuracy at time 950 is 0.83
# acc on clean stream is 0.8444444444444444
# 5.873603364436745 0.8394519999999974
# [0.8394519999999974, [], [], [], []]
# --- 57.32132911682129 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.861
# Accuracy at time 100 is 0.864
# Accuracy at time 150 is 0.868
# Accuracy at time 200 is 0.863
# Accuracy at time 250 is 0.863
# Accuracy at time 300 is 0.847
# Accuracy at time 350 is 0.834
# Accuracy at time 400 is 0.849
# Accuracy at time 450 is 0.851
# Accuracy at time 500 is 0.859
# Accuracy at time 550 is 0.848
# Accuracy at time 600 is 0.846
# Accuracy at time 650 is 0.842
# Accuracy at time 700 is 0.827
# Accuracy at time 750 is 0.836
# Accuracy at time 800 is 0.833
# Accuracy at time 850 is 0.842
# Accuracy at time 900 is 0.838
# Accuracy at time 950 is 0.841
# acc on clean stream is 0.8444444444444444
# 6.905138157495109 0.8457910000000007
# [0.8394519999999974, 0.8457910000000007, [], [], []]
# --- 114.38941478729248 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.862
# Accuracy at time 100 is 0.88
# Accuracy at time 150 is 0.879
# Accuracy at time 200 is 0.885
# Accuracy at time 250 is 0.876
# Accuracy at time 300 is 0.853
# Accuracy at time 350 is 0.835
# Accuracy at time 400 is 0.868
# Accuracy at time 450 is 0.875
# Accuracy at time 500 is 0.874
# Accuracy at time 550 is 0.864
# Accuracy at time 600 is 0.862
# Accuracy at time 650 is 0.856
# Accuracy at time 700 is 0.841
# Accuracy at time 750 is 0.852
# Accuracy at time 800 is 0.85
# Accuracy at time 850 is 0.858
# Accuracy at time 900 is 0.846
# Accuracy at time 950 is 0.847
# acc on clean stream is 0.8633333333333333
# 7.852809741062167 0.858949000000003
# [0.8394519999999974, 0.8457910000000007, 0.858949000000003, [], []]
# --- 173.14288973808289 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.868
# Accuracy at time 100 is 0.88
# Accuracy at time 150 is 0.885
# Accuracy at time 200 is 0.883
# Accuracy at time 250 is 0.881
# Accuracy at time 300 is 0.853
# Accuracy at time 350 is 0.819
# Accuracy at time 400 is 0.866
# Accuracy at time 450 is 0.877
# Accuracy at time 500 is 0.884
# Accuracy at time 550 is 0.878
# Accuracy at time 600 is 0.865
# Accuracy at time 650 is 0.853
# Accuracy at time 700 is 0.834
# Accuracy at time 750 is 0.86
# Accuracy at time 800 is 0.854
# Accuracy at time 850 is 0.871
# Accuracy at time 900 is 0.852
# Accuracy at time 950 is 0.844
# acc on clean stream is 0.8644444444444445
# 9.04583067227028 0.8620780000000002
# [0.8394519999999974, 0.8457910000000007, 0.858949000000003, 0.8620780000000002, []]
# --- 229.93903470039368 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.829
# Accuracy at time 100 is 0.835
# Accuracy at time 150 is 0.855
# Accuracy at time 200 is 0.875
# Accuracy at time 250 is 0.847
# Accuracy at time 300 is 0.707
# Accuracy at time 350 is 0.698
# Accuracy at time 400 is 0.847
# Accuracy at time 450 is 0.851
# Accuracy at time 500 is 0.871
# Accuracy at time 550 is 0.809
# Accuracy at time 600 is 0.79
# Accuracy at time 650 is 0.761
# Accuracy at time 700 is 0.738
# Accuracy at time 750 is 0.849
# Accuracy at time 800 is 0.832
# Accuracy at time 850 is 0.868
# Accuracy at time 900 is 0.773
# Accuracy at time 950 is 0.785
# acc on clean stream is 0.8066666666666666
# 14.03859315480033 0.8021280000000004
# [0.8394519999999974, 0.8457910000000007, 0.858949000000003, 0.8620780000000002, 0.8021280000000004]
# --- 286.59422850608826 seconds ---
# ./results/fully_fashionMNIST_greedy_L2_all-pts_0
# ./results/fully_fashionMNIST_greedy_L2_all-pts_0
# Running the 0-th experiment
# Initial accuracy is 0.499
# Target accuracy is 0.01
# [5.873603364436745, 6.905138157495109, 7.852809741062167, 9.04583067227028, 14.03859315480033]
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.848
# Accuracy at time 100 is 0.852
# Accuracy at time 150 is 0.857
# Accuracy at time 200 is 0.848
# Accuracy at time 250 is 0.851
# Accuracy at time 300 is 0.845
# Accuracy at time 350 is 0.833
# Accuracy at time 400 is 0.846
# Accuracy at time 450 is 0.846
# Accuracy at time 500 is 0.846
# Accuracy at time 550 is 0.841
# Accuracy at time 600 is 0.842
# Accuracy at time 650 is 0.841
# Accuracy at time 700 is 0.828
# Accuracy at time 750 is 0.829
# Accuracy at time 800 is 0.828
# Accuracy at time 850 is 0.828
# Accuracy at time 900 is 0.826
# Accuracy at time 950 is 0.825
# acc on clean stream is 0.8422222222222222
# 5.873603364436745 0.8343800000000008
# [0.8343800000000008, [], [], [], []]
# --- 118.9501211643219 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.864
# Accuracy at time 100 is 0.865
# Accuracy at time 150 is 0.868
# Accuracy at time 200 is 0.864
# Accuracy at time 250 is 0.862
# Accuracy at time 300 is 0.847
# Accuracy at time 350 is 0.833
# Accuracy at time 400 is 0.848
# Accuracy at time 450 is 0.848
# Accuracy at time 500 is 0.853
# Accuracy at time 550 is 0.846
# Accuracy at time 600 is 0.842
# Accuracy at time 650 is 0.836
# Accuracy at time 700 is 0.818
# Accuracy at time 750 is 0.828
# Accuracy at time 800 is 0.828
# Accuracy at time 850 is 0.835
# Accuracy at time 900 is 0.831
# Accuracy at time 950 is 0.833
# acc on clean stream is 0.8433333333333334
# 6.905138157495109 0.8427899999999983
# [0.8343800000000008, 0.8427899999999983, [], [], []]
# --- 226.3425612449646 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.864
# Accuracy at time 100 is 0.88
# Accuracy at time 150 is 0.879
# Accuracy at time 200 is 0.885
# Accuracy at time 250 is 0.874
# Accuracy at time 300 is 0.852
# Accuracy at time 350 is 0.829
# Accuracy at time 400 is 0.864
# Accuracy at time 450 is 0.873
# Accuracy at time 500 is 0.872
# Accuracy at time 550 is 0.862
# Accuracy at time 600 is 0.855
# Accuracy at time 650 is 0.848
# Accuracy at time 700 is 0.833
# Accuracy at time 750 is 0.84
# Accuracy at time 800 is 0.842
# Accuracy at time 850 is 0.852
# Accuracy at time 900 is 0.837
# Accuracy at time 950 is 0.841
# acc on clean stream is 0.86
# 7.852809741062167 0.855088
# [0.8343800000000008, 0.8427899999999983, 0.855088, [], []]
# --- 343.1929156780243 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.871
# Accuracy at time 100 is 0.882
# Accuracy at time 150 is 0.885
# Accuracy at time 200 is 0.881
# Accuracy at time 250 is 0.879
# Accuracy at time 300 is 0.852
# Accuracy at time 350 is 0.818
# Accuracy at time 400 is 0.867
# Accuracy at time 450 is 0.876
# Accuracy at time 500 is 0.884
# Accuracy at time 550 is 0.878
# Accuracy at time 600 is 0.863
# Accuracy at time 650 is 0.849
# Accuracy at time 700 is 0.829
# Accuracy at time 750 is 0.856
# Accuracy at time 800 is 0.854
# Accuracy at time 850 is 0.868
# Accuracy at time 900 is 0.85
# Accuracy at time 950 is 0.843
# acc on clean stream is 0.8633333333333333
# 9.04583067227028 0.8603670000000004
# [0.8343800000000008, 0.8427899999999983, 0.855088, 0.8603670000000004, []]
# --- 444.9932243824005 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.862
# Accuracy at time 100 is 0.86
# Accuracy at time 150 is 0.866
# Accuracy at time 200 is 0.884
# Accuracy at time 250 is 0.872
# Accuracy at time 300 is 0.756
# Accuracy at time 350 is 0.852
# Accuracy at time 400 is 0.887
# Accuracy at time 450 is 0.882
# Accuracy at time 500 is 0.89
# Accuracy at time 550 is 0.833
# Accuracy at time 600 is 0.807
# Accuracy at time 650 is 0.791
# Accuracy at time 700 is 0.806
# Accuracy at time 750 is 0.894
# Accuracy at time 800 is 0.863
# Accuracy at time 850 is 0.885
# Accuracy at time 900 is 0.8
# Accuracy at time 950 is 0.824
# acc on clean stream is 0.8244444444444444
# 14.03859315480033 0.830081999999999
# [0.8343800000000008, 0.8427899999999983, 0.855088, 0.8603670000000004, 0.830081999999999]
# --- 551.2628259658813 seconds ---
# ./results/fully_fashionMNIST_semi-online_L2_all-pts_0
# ./results/fully_fashionMNIST_semi-online_L2_all-pts_0

# %%
defense_method = "slab"
defense = {defense_method:0}

for attack_method in attack_methods:
    defense_range = "all-pts"
    w_list3, (X_test, Y_test) = experiment(dataset)
    res3 = [test_accuracy(X_test, Y_test, w) for w in w_list3[-1]]
# Out:
# Running the 0-th experiment
# Initial accuracy is 0.499
# Target accuracy is 0.01
# [6.779656432481225, 11.644085100338394, 17.264378418085613, 32.042097807863875, 71.17228956428355]
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.915
# Accuracy at time 100 is 0.918
# Accuracy at time 150 is 0.919
# Accuracy at time 200 is 0.92
# Accuracy at time 250 is 0.917
# Accuracy at time 300 is 0.922
# Accuracy at time 350 is 0.92
# Accuracy at time 400 is 0.92
# Accuracy at time 450 is 0.92
# Accuracy at time 500 is 0.92
# Accuracy at time 550 is 0.919
# Accuracy at time 600 is 0.918
# Accuracy at time 650 is 0.917
# Accuracy at time 700 is 0.918
# Accuracy at time 750 is 0.92
# Accuracy at time 800 is 0.918
# Accuracy at time 850 is 0.917
# Accuracy at time 900 is 0.917
# Accuracy at time 950 is 0.917
# acc on clean stream is 0.9077777777777778
# 6.779656432481225 0.9168190000000103
# [0.9168190000000103, [], [], [], []]
# --- 3.1035523414611816 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.916
# Accuracy at time 100 is 0.918
# Accuracy at time 150 is 0.923
# Accuracy at time 200 is 0.923
# Accuracy at time 250 is 0.924
# Accuracy at time 300 is 0.92
# Accuracy at time 350 is 0.921
# Accuracy at time 400 is 0.921
# Accuracy at time 450 is 0.921
# Accuracy at time 500 is 0.922
# Accuracy at time 550 is 0.921
# Accuracy at time 600 is 0.921
# Accuracy at time 650 is 0.922
# Accuracy at time 700 is 0.922
# Accuracy at time 750 is 0.922
# Accuracy at time 800 is 0.921
# Accuracy at time 850 is 0.921
# Accuracy at time 900 is 0.921
# Accuracy at time 950 is 0.92
# acc on clean stream is 0.9111111111111111
# 11.644085100338394 0.9193350000000166
# [0.9168190000000103, 0.9193350000000166, [], [], []]
# --- 7.234555959701538 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.917
# Accuracy at time 100 is 0.918
# Accuracy at time 150 is 0.918
# Accuracy at time 200 is 0.921
# Accuracy at time 250 is 0.923
# Accuracy at time 300 is 0.923
# Accuracy at time 350 is 0.923
# Accuracy at time 400 is 0.924
# Accuracy at time 450 is 0.923
# Accuracy at time 500 is 0.925
# Accuracy at time 550 is 0.926
# Accuracy at time 600 is 0.925
# Accuracy at time 650 is 0.926
# Accuracy at time 700 is 0.926
# Accuracy at time 750 is 0.926
# Accuracy at time 800 is 0.926
# Accuracy at time 850 is 0.926
# Accuracy at time 900 is 0.927
# Accuracy at time 950 is 0.926
# acc on clean stream is 0.9133333333333333
# 17.264378418085613 0.9219860000000092
# [0.9168190000000103, 0.9193350000000166, 0.9219860000000092, [], []]
# --- 10.616077423095703 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.922
# Accuracy at time 100 is 0.923
# Accuracy at time 150 is 0.924
# Accuracy at time 200 is 0.933
# Accuracy at time 250 is 0.931
# Accuracy at time 300 is 0.931
# Accuracy at time 350 is 0.929
# Accuracy at time 400 is 0.934
# Accuracy at time 450 is 0.932
# Accuracy at time 500 is 0.933
# Accuracy at time 550 is 0.937
# Accuracy at time 600 is 0.933
# Accuracy at time 650 is 0.933
# Accuracy at time 700 is 0.937
# Accuracy at time 750 is 0.937
# Accuracy at time 800 is 0.934
# Accuracy at time 850 is 0.934
# Accuracy at time 900 is 0.932
# Accuracy at time 950 is 0.93
# acc on clean stream is 0.9233333333333333
# 32.042097807863875 0.9298999999999917
# [0.9168190000000103, 0.9193350000000166, 0.9219860000000092, 0.9298999999999917, []]
# --- 14.30830717086792 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.894
# Accuracy at time 100 is 0.889
# Accuracy at time 150 is 0.889
# Accuracy at time 200 is 0.89
# Accuracy at time 250 is 0.892
# Accuracy at time 300 is 0.841
# Accuracy at time 350 is 0.801
# Accuracy at time 400 is 0.86
# Accuracy at time 450 is 0.863
# Accuracy at time 500 is 0.88
# Accuracy at time 550 is 0.873
# Accuracy at time 600 is 0.854
# Accuracy at time 650 is 0.832
# Accuracy at time 700 is 0.818
# Accuracy at time 750 is 0.856
# Accuracy at time 800 is 0.858
# Accuracy at time 850 is 0.881
# Accuracy at time 900 is 0.843
# Accuracy at time 950 is 0.837
# acc on clean stream is 0.8533333333333334
# 71.17228956428355 0.858960000000001
# [0.9168190000000103, 0.9193350000000166, 0.9219860000000092, 0.9298999999999917, 0.858960000000001]
# --- 17.675408601760864 seconds ---
# ./results/fully_fashionMNIST_simplistic_slab_all-pts_0
# ./results/fully_fashionMNIST_simplistic_slab_all-pts_0
# Running the 0-th experiment
# Initial accuracy is 0.499
# Target accuracy is 0.01
# [6.779656432481225, 11.644085100338394, 17.264378418085613, 32.042097807863875, 71.17228956428355]
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.87
# Accuracy at time 100 is 0.886
# Accuracy at time 150 is 0.891
# Accuracy at time 200 is 0.891
# Accuracy at time 250 is 0.892
# Accuracy at time 300 is 0.896
# Accuracy at time 350 is 0.896
# Accuracy at time 400 is 0.896
# Accuracy at time 450 is 0.897
# Accuracy at time 500 is 0.899
# Accuracy at time 550 is 0.899
# Accuracy at time 600 is 0.898
# Accuracy at time 650 is 0.898
# Accuracy at time 700 is 0.898
# Accuracy at time 750 is 0.899
# Accuracy at time 800 is 0.899
# Accuracy at time 850 is 0.899
# Accuracy at time 900 is 0.899
# Accuracy at time 950 is 0.899
# acc on clean stream is 0.8833333333333333
# 6.779656432481225 0.8931850000000047
# [0.8931850000000047, [], [], [], []]
# --- 65.13210701942444 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.881
# Accuracy at time 100 is 0.891
# Accuracy at time 150 is 0.897
# Accuracy at time 200 is 0.897
# Accuracy at time 250 is 0.896
# Accuracy at time 300 is 0.898
# Accuracy at time 350 is 0.897
# Accuracy at time 400 is 0.899
# Accuracy at time 450 is 0.9
# Accuracy at time 500 is 0.901
# Accuracy at time 550 is 0.901
# Accuracy at time 600 is 0.901
# Accuracy at time 650 is 0.901
# Accuracy at time 700 is 0.901
# Accuracy at time 750 is 0.903
# Accuracy at time 800 is 0.903
# Accuracy at time 850 is 0.903
# Accuracy at time 900 is 0.902
# Accuracy at time 950 is 0.903
# acc on clean stream is 0.8944444444444445
# 11.644085100338394 0.8968319999999987
# [0.8931850000000047, 0.8968319999999987, [], [], []]
# --- 126.77199935913086 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.883
# Accuracy at time 100 is 0.89
# Accuracy at time 150 is 0.896
# Accuracy at time 200 is 0.902
# Accuracy at time 250 is 0.9
# Accuracy at time 300 is 0.899
# Accuracy at time 350 is 0.898
# Accuracy at time 400 is 0.902
# Accuracy at time 450 is 0.902
# Accuracy at time 500 is 0.903
# Accuracy at time 550 is 0.901
# Accuracy at time 600 is 0.9
# Accuracy at time 650 is 0.901
# Accuracy at time 700 is 0.901
# Accuracy at time 750 is 0.906
# Accuracy at time 800 is 0.906
# Accuracy at time 850 is 0.906
# Accuracy at time 900 is 0.907
# Accuracy at time 950 is 0.907
# acc on clean stream is 0.8933333333333333
# 17.264378418085613 0.8985310000000015
# [0.8931850000000047, 0.8968319999999987, 0.8985310000000015, [], []]
# --- 191.80041074752808 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.88
# Accuracy at time 100 is 0.888
# Accuracy at time 150 is 0.894
# Accuracy at time 200 is 0.899
# Accuracy at time 250 is 0.895
# Accuracy at time 300 is 0.888
# Accuracy at time 350 is 0.883
# Accuracy at time 400 is 0.892
# Accuracy at time 450 is 0.893
# Accuracy at time 500 is 0.897
# Accuracy at time 550 is 0.89
# Accuracy at time 600 is 0.887
# Accuracy at time 650 is 0.886
# Accuracy at time 700 is 0.888
# Accuracy at time 750 is 0.894
# Accuracy at time 800 is 0.89
# Accuracy at time 850 is 0.897
# Accuracy at time 900 is 0.888
# Accuracy at time 950 is 0.886
# acc on clean stream is 0.8822222222222222
# 32.042097807863875 0.8886189999999997
# [0.8931850000000047, 0.8968319999999987, 0.8985310000000015, 0.8886189999999997, []]
# --- 260.9499251842499 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.842
# Accuracy at time 100 is 0.848
# Accuracy at time 150 is 0.862
# Accuracy at time 200 is 0.875
# Accuracy at time 250 is 0.865
# Accuracy at time 300 is 0.806
# Accuracy at time 350 is 0.786
# Accuracy at time 400 is 0.848
# Accuracy at time 450 is 0.861
# Accuracy at time 500 is 0.873
# Accuracy at time 550 is 0.84
# Accuracy at time 600 is 0.832
# Accuracy at time 650 is 0.823
# Accuracy at time 700 is 0.808
# Accuracy at time 750 is 0.85
# Accuracy at time 800 is 0.841
# Accuracy at time 850 is 0.87
# Accuracy at time 900 is 0.828
# Accuracy at time 950 is 0.835
# acc on clean stream is 0.8433333333333334
# 71.17228956428355 0.8383410000000011
# [0.8931850000000047, 0.8968319999999987, 0.8985310000000015, 0.8886189999999997, 0.8383410000000011]
# --- 327.77015924453735 seconds ---
# ./results/fully_fashionMNIST_greedy_slab_all-pts_0
# ./results/fully_fashionMNIST_greedy_slab_all-pts_0
# Running the 0-th experiment
# Initial accuracy is 0.499
# Target accuracy is 0.01
# [6.779656432481225, 11.644085100338394, 17.264378418085613, 32.042097807863875, 71.17228956428355]
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.868
# Accuracy at time 100 is 0.889
# Accuracy at time 150 is 0.892
# Accuracy at time 200 is 0.891
# Accuracy at time 250 is 0.889
# Accuracy at time 300 is 0.894
# Accuracy at time 350 is 0.894
# Accuracy at time 400 is 0.895
# Accuracy at time 450 is 0.896
# Accuracy at time 500 is 0.898
# Accuracy at time 550 is 0.898
# Accuracy at time 600 is 0.896
# Accuracy at time 650 is 0.896
# Accuracy at time 700 is 0.897
# Accuracy at time 750 is 0.897
# Accuracy at time 800 is 0.896
# Accuracy at time 850 is 0.896
# Accuracy at time 900 is 0.896
# Accuracy at time 950 is 0.896
# acc on clean stream is 0.8833333333333333
# 6.779656432481225 0.891887999999994
# [0.891887999999994, [], [], [], []]
# --- 106.7113127708435 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.878
# Accuracy at time 100 is 0.893
# Accuracy at time 150 is 0.898
# Accuracy at time 200 is 0.898
# Accuracy at time 250 is 0.895
# Accuracy at time 300 is 0.897
# Accuracy at time 350 is 0.897
# Accuracy at time 400 is 0.898
# Accuracy at time 450 is 0.899
# Accuracy at time 500 is 0.9
# Accuracy at time 550 is 0.899
# Accuracy at time 600 is 0.898
# Accuracy at time 650 is 0.9
# Accuracy at time 700 is 0.899
# Accuracy at time 750 is 0.899
# Accuracy at time 800 is 0.899
# Accuracy at time 850 is 0.899
# Accuracy at time 900 is 0.899
# Accuracy at time 950 is 0.901
# acc on clean stream is 0.8911111111111111
# 11.644085100338394 0.8956429999999935
# [0.891887999999994, 0.8956429999999935, [], [], []]
# --- 212.1299979686737 seconds ---
# Accuracy at time 0 is 0.499
# Accuracy at time 50 is 0.884
# Accuracy at time 100 is 0.893
# Accuracy at time 150 is 0.899
# Accuracy at time 200 is 0.902
# Accuracy at time 250 is 0.9
# Accuracy at time 300 is 0.897
# Accuracy at time 350 is 0.899
# Accuracy at time 400 is 0.902
# Accuracy at time 450 is 0.901
# Accuracy at time 500 is 0.903
# Accuracy at time 550 is 0.901
# Accuracy at time 600 is 0.901
# Accuracy at time 650 is 0.901
# Accuracy at time 700 is 0.9
# Accuracy at time 750 is 0.901
# Accuracy at time 800 is 0.899
# Accuracy at time 850 is 0.899
# Accuracy at time 900 is 0.901
# Accuracy at time 950 is 0.9
# acc on clean stream is 0.89
# 17.264378418085613 0.8967599999999908
# [0.891887999999994, 0.8956429999999935, 0.8967599999999908, [], []]
# --- 326.9432489871979 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.878
# Accuracy at time 100 is 0.89
# Accuracy at time 150 is 0.894
# Accuracy at time 200 is 0.898
# Accuracy at time 250 is 0.89
# Accuracy at time 300 is 0.891
# Accuracy at time 350 is 0.882
# Accuracy at time 400 is 0.891
# Accuracy at time 450 is 0.892
# Accuracy at time 500 is 0.892
# Accuracy at time 550 is 0.887
# Accuracy at time 600 is 0.88
# Accuracy at time 650 is 0.884
# Accuracy at time 700 is 0.882
# Accuracy at time 750 is 0.885
# Accuracy at time 800 is 0.885
# Accuracy at time 850 is 0.893
# Accuracy at time 900 is 0.886
# Accuracy at time 950 is 0.883
# acc on clean stream is 0.8822222222222222
# 32.042097807863875 0.8858969999999975
# [0.891887999999994, 0.8956429999999935, 0.8967599999999908, 0.8858969999999975, []]
# --- 455.1431336402893 seconds ---
# Accuracy at time 0 is 0.442
# Accuracy at time 50 is 0.856
# Accuracy at time 100 is 0.856
# Accuracy at time 150 is 0.865
# Accuracy at time 200 is 0.878
# Accuracy at time 250 is 0.864
# Accuracy at time 300 is 0.809
# Accuracy at time 350 is 0.81
# Accuracy at time 400 is 0.868
# Accuracy at time 450 is 0.872
# Accuracy at time 500 is 0.876
# Accuracy at time 550 is 0.841
# Accuracy at time 600 is 0.831
# Accuracy at time 650 is 0.822
# Accuracy at time 700 is 0.81
# Accuracy at time 750 is 0.86
# Accuracy at time 800 is 0.847
# Accuracy at time 850 is 0.876
# Accuracy at time 900 is 0.832
# Accuracy at time 950 is 0.836
# acc on clean stream is 0.8444444444444444
# 71.17228956428355 0.8420930000000009
# [0.891887999999994, 0.8956429999999935, 0.8967599999999908, 0.8858969999999975, 0.8420930000000009]
# --- 571.1905043125153 seconds ---
# ./results/fully_fashionMNIST_semi-online_slab_all-pts_0
# ./results/fully_fashionMNIST_semi-online_slab_all-pts_0
